# %%
# Colab
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/DS Project - Moderately/code')

# %%
from inference import predict
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# ideology
# - 0 Strong conservative bias
# - 1 Somewhat conservative bias
# - 2 Moderate/Neutral/No bias
# - 3 Somewhat liberal bias
# - 4 Strongly liberal bias
#
# factuality
# - 0 Entirely factual
# - 1 Either/Both
# - 2 Opinionated

# %%
tests = [
    "Trump has strengthened the immigration laws, allowing for Americans to prosper in lower unemployment and higher economic growth.",
    "Global warming has led in water levels rising by an inch compared to last year. The current administration has not yet announced any laws addressing climate change.",
    "The lies of the right-wing media have gone too far. We should stand up and fight against white nationalism ruining the foundations of this country."
]

for text in tests:
    print(f"> {text}\n→ {predict(text)}\n")
# Out:
# > Trump has strengthened the immigration laws, allowing for Americans to prosper in lower unemployment and higher economic growth.
# → {'ideology_id': 1, 'factuality_id': 1, 'ideology': 'somewhat conservative bias', 'factuality': 'mix of factual and opinionated claims', 'ideology_color': 'red', 'factuality_color': 'grey', 'analysis_html': "This text may contain <span style='color:red'>somewhat conservative bias</span> and is made up of <span style='color:grey'>mix of factual and opinionated claims</span>."}
#
# > Global warming has led in water levels rising by an inch compared to last year. The current administration has not yet announced any laws addressing climate change.
# ...
